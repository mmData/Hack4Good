# %% [markdown]
# This is an example notebook on how to use the functions implemented in utils. For this purpose we set up a dummy task - a NLP text classification. The Data is not present in the data folder such that the code will not compile. Nevertheless, we hope that the current Notebooks gives some insights into how to use the functions in utils.

# %%
# Do not run this line more than once! Otherwise restart kernel
import os
print('Initial wdir: ' + os.getcwd())
os.chdir('../../../')
print('Current wdir: ' + os.getcwd())
# Out:
# Initial wdir: C:\Users\redur\Documents\team-black\notebooks\Max_Muster\models_german
# Current wdir: C:\Users\redur\Documents\team-black

# %%
from src.utils.exploration import test_model, cross_validation
from src.utils.evaluation import plot_confusion_matrix, plot_learning_curve, auc_plot, wrongly_classified, print_metrics

import numpy as np
import pandas as pd
pd.set_option('display.max_colwidth', -1)
import matplotlib
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
# Code will not compile since data is not present in the data folder
data = pd.read_csv('./data/raw/train.csv')

# %%
X = data['text']
y = data['author']
X_train, X_test, y_train, y_test = train_test_split(data['text'], data['author'], test_size=0.33, random_state=42)

# %%
# Create list of Pipelines / Models
list_model = [(Pipeline([('vect', CountVectorizer()),
                         ('multNB', MultinomialNB(alpha=0.22))]),
               'Naive Bayes'),
              (Pipeline([('vect', CountVectorizer()),
                         ('tfidf', TfidfTransformer()),
                         ('multNB', MultinomialNB(alpha=0.03))]),
               'Naive Bayes with tfidf')]

# %%
# Learn and evaluate all models in list_models
for model in list_model:
    test_model(model[0], model[1], X_train, y_train, X_test, y_test, details=True, normalize=True)
# Out:
# #############################################
#  model: Naive Bayes
# #############################################
# the list of steps and parameters in the pipeline
#
# vect: CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)
#
# multNB: MultinomialNB(alpha=0.22, class_prior=None, fit_prior=True)
#
# accuracy on test set:
#  0.8367378520581863 %
#
# accuracy on train set:
#  0.9375619425173439 %
#
# classification report:
#                precision    recall  f1-score   support
#
#          EAP       0.86      0.81      0.83      2587
#          HPL       0.85      0.84      0.85      1852
#          MWS       0.80      0.87      0.83      2023
#
#    micro avg       0.84      0.84      0.84      6462
#    macro avg       0.84      0.84      0.84      6462
# weighted avg       0.84      0.84      0.84      6462
#
#
# confusion matrix:
#  [[2095  178  314]
#  [ 170 1557  125]
#  [ 171   97 1755]]
#
# Actual labels:
#   EAP 2587
#   HPL 1852
#   MWS 2023
#
# Predicted labels:
#   EAP 2436
#   HPL 1832
#   MWS 2194
#
# Normalized confusion matrix
# length of the vocabulary vector :
# 21573 21573
#
#         term  count
# 19020  the    11641
# 13029  of     6835
# 739    and    5805
# 19290  to     4234
# 9647   in     3049
# 20926  was    2115
# 19016  that   2089
# 12458  my     1801
# 10372  it     1618
# 8680   had    1514
# 21271  with   1511
# 8869   he     1466
# 9100   his    1351
# 1137   as     1299
# 7662   for    1159
# 2536   but    1149
# 21099  which  1097
# 12809  not    1075
# 1266   at     1024
# 11758  me     1001
# 7893   from   934
# 2557   by     909
# 10347  is     900
# 19100  this   874
# 13091  on     859
# 1683   be     812
# 21046  were   745
# 9005   her    717
# 8848   have   706
# 21509  you    666
#                   term  count
# 10102  insupportable    0
# 10106  insurrection     0
# 10107  int              0
# 10110  integrated       0
# 10115  intellectuality  0
# 10116  intellectually   0
# 10118  intelligences    0
# 10121  intemperance     0
# 10128  intensest        0
# 21572  υπνος            0
#
#      ('υπνος', 21572)
#      ('élite', 21571)
#      ('æschylus', 21570)
#      ('ærostation', 21569)
#      ('æronauts', 21568)
#      ('æronaut', 21567)
#      ('æneid', 21566)
#      ('æmilianus', 21565)
#      ('ægyptus', 21564)
#      ('ædile', 21563)
#      ('ångstrom', 21562)
#      ('zuro', 21561)
#      ('zorry', 21560)
#      ('zopyrus', 21559)
#      ('zones', 21558)
#      ('zone', 21557)
#      ('zokkar', 21556)
#      ('zodiacal', 21555)
#      ('zodiac', 21554)
#      ('zobnarian', 21553)
#      ('zobna', 21552)
# more frequent words:
# [('υπνος', 21572), ('élite', 21571), ('æschylus', 21570), ('ærostation', 21569), ('æronauts', 21568), ('æronaut', 21567), ('æneid', 21566), ('æmilianus', 21565), ('ægyptus', 21564), ('ædile', 21563), ('ångstrom', 21562), ('zuro', 21561), ('zorry', 21560), ('zopyrus', 21559), ('zones', 21558), ('zone', 21557), ('zokkar', 21556), ('zodiacal', 21555), ('zodiac', 21554), ('zobnarian', 21553)]
#
# less frequent words:
# [('abernethy', 19), ('abdul', 18), ('abdication', 17), ('abdicated', 16), ('abbé', 15), ('abbreviation', 14), ('abbey', 13), ('abatement', 12), ('abate', 11), ('abashment', 10), ('abashed', 9), ('abasement', 8), ('abased', 7), ('abaout', 6), ('abandonment', 5), ('abandoning', 4), ('abandoned', 3), ('abandon', 2), ('aback', 1)]
#
# Model's parameters:
# Smallest coeff:
# ['abaout', 'abashment', 'abate', 'abatement', 'abbey', 'abdicated', 'abdul', 'aberrant', 'aberrations', 'abhor', 'abhorred', 'abhorrent', 'abigail', 'abijah', 'abjure', 'ablaze', 'ably', 'abnormalities', 'abnormality', 'aboard']
# [-13.318065169776785, -13.318065169776785, -13.318065169776785, -13.318065169776785, -13.318065169776785, -13.318065169776785, -13.318065169776785, -13.318065169776785, -13.318065169776785, -13.318065169776785, -13.318065169776785, -13.318065169776785, -13.318065169776785, -13.318065169776785, -13.318065169776785, -13.318065169776785, -13.318065169776785, -13.318065169776785, -13.318065169776785, -13.318065169776785]
#
# Largest coeff:
# ['the', 'of', 'and', 'to', 'in', 'it', 'that', 'was', 'my', 'is', 'with', 'at', 'as', 'which', 'had', 'for', 'his', 'he', 'not', 'this']
# [-2.580560412802509, -3.0880212640139852, -3.533868038431981, -3.7289086085420617, -3.8607865979206757, -4.420432568612692, -4.451996461945109, -4.475355642944009, -4.7120123105133, -4.790723647308733, -4.790723647308733, -4.806140377490213, -4.886014029249246, -4.922300286319931, -5.015844458533558, -5.021495979136907, -5.022630126153183, -5.043267853870013, -5.044426978628874, -5.046749266660778]
#
#
# #############################################
#  model: Naive Bayes with tfidf
# #############################################
# the list of steps and parameters in the pipeline
#
# vect: CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)
#
# tfidf: TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)
#
# multNB: MultinomialNB(alpha=0.03, class_prior=None, fit_prior=True)
#
# accuracy on test set:
#  0.832559579077685 %
#
# accuracy on train set:
#  0.9630250819547153 %
#
# classification report:
#                precision    recall  f1-score   support
#
#          EAP       0.83      0.84      0.83      2587
#          HPL       0.86      0.82      0.84      1852
#          MWS       0.81      0.84      0.83      2023
#
#    micro avg       0.83      0.83      0.83      6462
#    macro avg       0.83      0.83      0.83      6462
# weighted avg       0.83      0.83      0.83      6462
#
#
# confusion matrix:
#  [[2163  153  271]
#  [ 218 1515  119]
#  [ 228   93 1702]]
#
# Actual labels:
#   EAP 2587
#   HPL 1852
#   MWS 2023
#
# Predicted labels:
#   EAP 2609
#   HPL 1761
#   MWS 2092
#
# Normalized confusion matrix
# length of the vocabulary vector :
# 21573 21573
#
#         term  count
# 19020  the    11641
# 13029  of     6835
# 739    and    5805
# 19290  to     4234
# 9647   in     3049
# 20926  was    2115
# 19016  that   2089
# 12458  my     1801
# 10372  it     1618
# 8680   had    1514
# 21271  with   1511
# 8869   he     1466
# 9100   his    1351
# 1137   as     1299
# 7662   for    1159
# 2536   but    1149
# 21099  which  1097
# 12809  not    1075
# 1266   at     1024
# 11758  me     1001
# 7893   from   934
# 2557   by     909
# 10347  is     900
# 19100  this   874
# 13091  on     859
# 1683   be     812
# 21046  were   745
# 9005   her    717
# 8848   have   706
# 21509  you    666
#                   term  count
# 10102  insupportable    0
# 10106  insurrection     0
# 10107  int              0
# 10110  integrated       0
# 10115  intellectuality  0
# 10116  intellectually   0
# 10118  intelligences    0
# 10121  intemperance     0
# 10128  intensest        0
# 21572  υπνος            0
#
#      ('υπνος', 21572)
#      ('élite', 21571)
#      ('æschylus', 21570)
#      ('ærostation', 21569)
#      ('æronauts', 21568)
#      ('æronaut', 21567)
#      ('æneid', 21566)
#      ('æmilianus', 21565)
#      ('ægyptus', 21564)
#      ('ædile', 21563)
#      ('ångstrom', 21562)
#      ('zuro', 21561)
#      ('zorry', 21560)
#      ('zopyrus', 21559)
#      ('zones', 21558)
#      ('zone', 21557)
#      ('zokkar', 21556)
#      ('zodiacal', 21555)
#      ('zodiac', 21554)
#      ('zobnarian', 21553)
#      ('zobna', 21552)
# more frequent words:
# [('υπνος', 21572), ('élite', 21571), ('æschylus', 21570), ('ærostation', 21569), ('æronauts', 21568), ('æronaut', 21567), ('æneid', 21566), ('æmilianus', 21565), ('ægyptus', 21564), ('ædile', 21563), ('ångstrom', 21562), ('zuro', 21561), ('zorry', 21560), ('zopyrus', 21559), ('zones', 21558), ('zone', 21557), ('zokkar', 21556), ('zodiacal', 21555), ('zodiac', 21554), ('zobnarian', 21553)]
#
# less frequent words:
# [('abernethy', 19), ('abdul', 18), ('abdication', 17), ('abdicated', 16), ('abbé', 15), ('abbreviation', 14), ('abbey', 13), ('abatement', 12), ('abate', 11), ('abashment', 10), ('abashed', 9), ('abasement', 8), ('abased', 7), ('abaout', 6), ('abandonment', 5), ('abandoning', 4), ('abandoned', 3), ('abandon', 2), ('aback', 1)]
#
#        term     tfidf
# 19020  the   0.079312
# 13029  of    0.054181
# 739    and   0.046511
# 19290  to    0.040837
# 9647   in    0.032156
# 20926  was   0.028005
# 12458  my    0.026371
# 19016  that  0.025621
# 10372  it    0.023735
# 8869   he    0.023352
# 8680   had   0.022729
# 21271  with  0.020957
# 9100   his   0.020754
# 1137   as    0.018994
# 2536   but   0.018765
# 12809  not   0.018440
# 7662   for   0.017691
# 11758  me    0.017109
# 10347  is    0.016789
# 19100  this  0.016354
#                   term  tfidf
# 10073  instigating      0.0
# 10074  instil           0.0
# 10078  instincts        0.0
# 10086  instructor       0.0
# 10087  instructress     0.0
# 10089  instrumental     0.0
# 10090  instrumentality  0.0
# 10093  insufferably     0.0
# 10098  insulting        0.0
# 10100  insults          0.0
# 10102  insupportable    0.0
# 10106  insurrection     0.0
# 10107  int              0.0
# 10110  integrated       0.0
# 10115  intellectuality  0.0
# 10116  intellectually   0.0
# 10118  intelligences    0.0
# 10121  intemperance     0.0
# 10128  intensest        0.0
# 21572  υπνος            0.0
#
# IDF:
# Smallest idf:
# ['the', 'of', 'and', 'to', 'in', 'was', 'that', 'it', 'my', 'with', 'had', 'he', 'but', 'as', 'for', 'which', 'at', 'not', 'his', 'from']
# [1.30982926649728, 1.5387569458680332, 1.5636259523791516, 1.8204470764636866, 2.0070374720583954, 2.257041049886446, 2.3382232060562007, 2.577774977821515, 2.6184738878441074, 2.680349291562195, 2.7174446054031627, 2.7832578239727344, 2.8330008228974384, 2.860545449043836, 2.860545449043836, 2.88836641873239, 2.8990021229392697, 2.9025726444576048, 2.9263586676134077, 3.0322426064708314]
#
# Largest idf:
# ['aaem', 'abased', 'abasement', 'abashed', 'abashment', 'abatement', 'abbey', 'abbé', 'abdicated', 'aberration', 'abide', 'abigail', 'abijah', 'abjure', 'ablaze', 'ably', 'aboard', 'abolished', 'abominations', 'aboriginal']
# [9.788593431293735, 9.788593431293735, 9.788593431293735, 9.788593431293735, 9.788593431293735, 9.788593431293735, 9.788593431293735, 9.788593431293735, 9.788593431293735, 9.788593431293735, 9.788593431293735, 9.788593431293735, 9.788593431293735, 9.788593431293735, 9.788593431293735, 9.788593431293735, 9.788593431293735, 9.788593431293735, 9.788593431293735, 9.788593431293735]
#
# Model's parameters:
# Smallest coeff:
# ['abaout', 'abashment', 'abate', 'abatement', 'abbey', 'abdicated', 'abdul', 'aberrant', 'aberrations', 'abhor', 'abhorred', 'abhorrent', 'abigail', 'abijah', 'abjure', 'ablaze', 'ably', 'abnormalities', 'abnormality', 'aboard']
# [-13.492669032670197, -13.492669032670197, -13.492669032670197, -13.492669032670197, -13.492669032670197, -13.492669032670197, -13.492669032670197, -13.492669032670197, -13.492669032670197, -13.492669032670197, -13.492669032670197, -13.492669032670197, -13.492669032670197, -13.492669032670197, -13.492669032670197, -13.492669032670197, -13.492669032670197, -13.492669032670197, -13.492669032670197, -13.492669032670197]
#
# Largest coeff:
# ['the', 'of', 'and', 'to', 'in', 'it', 'is', 'was', 'that', 'my', 'at', 'this', 'with', 'not', 'as', 'he', 'his', 'had', 'which', 'for']
# [-3.8992761106012948, -4.283262565523568, -4.699620626962644, -4.702856677269221, -4.754307404546372, -4.942808287089966, -5.064116814183681, -5.072684735890611, -5.202731328314128, -5.261442272900948, -5.3133095552243, -5.375381912673886, -5.396328521567573, -5.414548808722773, -5.442531489442524, -5.474169417926905, -5.508521357790536, -5.5140385921655675, -5.531407919952532, -5.532706467670295]

# %% [markdown]
# # Cross Validation

# %%
model_cv = Pipeline([('emb', CountVectorizer()),
                     ('ftrf', TfidfTransformer()),
                     ('clf', MultinomialNB(alpha=0.03))])

model_name = 'Naive Bayes with tfidf'

# %%
param_grid = {"clf__alpha": [0.001, 0.01, 0.05, 0.1],
              "emb__min_df": [1, 10, 100, 1000]
         }

# %%
cross_validation(model_cv, model_name, param_grid, X, y, folds=3, visualize=True, n_jobs=3)
# Out:
# Grid Cross Validation for the model: Naive Bayes with tfidf
# with parameters:
# clf__alpha: [0.001, 0.01, 0.05, 0.1]
# emb__min_df: [1, 10, 100, 1000]
# Number of Folds: 3
# Best estimator: Pipeline(memory=None,
#      steps=[('emb', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_...inear_tf=False, use_idf=True)), ('clf', MultinomialNB(alpha=0.1, class_prior=None, fit_prior=True))])
# Best score: 0.8406966647939118
#
# Best parameters:
# clf__alpha: 0.1
# emb__min_df: 1
# Time needed: 29.697627782821655s

# %% [markdown]
# #  Learning Curve

# %%
for model in list_model:
    plot_learning_curve(model[0], model[1], X, y, n_jobs=3, cv=5)

# %% [markdown]
# ## Area under Curve

# %%
for model in list_model:
    auc_plot(model[0], model[1], X_test, y_test, x_train=X_train, y_train=y_train)

# %% [markdown]
# ## Investigate wrongly classified data points

# %%
wrongly_classified(list_model[0][0], X_test, y_test, x_train=X_train, y_train=y_train)
# Out:
#       predicted_label true_label  \
# 13435  EAP             HPL
# 11277  HPL             EAP
# 8287   MWS             EAP
# 11993  MWS             EAP
# 18489  EAP             HPL
# 1153   MWS             EAP
# 19122  HPL             MWS
# 18539  EAP             MWS
# 17156  EAP             HPL
# 7524   MWS             EAP
# 14120  EAP             HPL
# 9543   MWS             EAP
# 7488   MWS             EAP
# 16705  EAP             MWS
# 6415   MWS             HPL
# 14283  MWS             EAP
# 6978   EAP             HPL
# 1383   MWS             HPL
# 16325  MWS             HPL
# 16999  MWS             HPL
# 1712   MWS             EAP
# 1290   MWS             EAP
# 11727  EAP             HPL
# 14142  MWS             HPL
# 1554   MWS             HPL
# 11906  EAP             MWS
# 7711   HPL             EAP
# 18217  HPL             EAP
# 19431  EAP             MWS
# 3894   EAP             HPL
# ...    ...             ...
# 8786   EAP             HPL
# 2473   MWS             EAP
# 1922   MWS             EAP
# 15518  HPL             EAP
# 18224  MWS             EAP
# 4130   HPL             EAP
# 18039  HPL             EAP
# 9785   HPL             MWS
# 14225  HPL             EAP
# 1954   EAP             HPL
# 1740   HPL             MWS
# 1345   MWS             EAP
# 11227  EAP             MWS
# 16095  MWS             HPL
# 19083  MWS             EAP
# 16321  EAP             MWS
# 19374  HPL             MWS
# 5312   EAP             HPL
# 13342  EAP             MWS
# 6880   MWS             EAP
# 12457  EAP             MWS
# 12841  EAP             MWS
# 12731  HPL             EAP
# 407    MWS             HPL
# 14695  MWS             HPL
# 7093   HPL             MWS
# 9966   MWS             EAP
# 14255  MWS             HPL
# 3056   HPL             EAP
# 11443  EAP             MWS
#
#                                                                                                                                                                                                                                                                      text
# 13435  Over those horrors the evil moon now hung very low, but the puffy worms of the sea need no moon to feed by.
# 11277  His chief amusements were gunning and fishing, or sauntering along the beach and through the myrtles, in quest of shells or entomological specimens; his collection of the latter might have been envied by a Swammerdamm.
# 8287   I will content myself with saying, in addition, that my temperament is sanguine, rash, ardent, enthusiastic and that all my life I have been a devoted admirer of the women.
# 11993  But my efforts were fruitless.
# 18489  John's, I bade the knocker enter, but was answered only by a shrill laugh.
# 1153   Impossible But let me hasten to the last eventful scene of the drama.
# 19122  Burke's Reflections on the French Revolution.
# 18539  "My best girl," he had said, "relieves me from these phantasies.
# 17156  That I had previously overestimated our depth, I was sure; but none the less we must still be deep enough to make these phenomena remarkable.
# 7524   The prospect was sublime.
# 14120  What we want, we may make about us; and what we don't want, we may sweep away.
# 9543   I need not remind the reader that, from the long and weird catalogue of human miseries, I might have selected many individual instances more replete with essential suffering than any of these vast generalities of disaster.
# 7488   Her voice grew more gentle grew more low yet I would not wish to dwell upon the wild meaning of the quietly uttered words.
# 16705  Nothing could exceed in beauty the contrast between these two excellent creatures.
# 6415   These were now fixed upon me, piercing my soul with their hatred, and rooting me to the spot whereon I stood.
# 14283  There is a countenance which haunts me, turn as I will.
# 6978   Of all its qualities, remoteness in the earth most impressed me.
# 1383   Yet from the first a taint of calamity, soon increased to boding significance, was apparent.
# 16325  And at last I resolved to scale that tower, fall though I might; since it were better to glimpse the sky and perish, than to live without ever beholding day.
# 16999  He had, he said, noticed me several times at my wanderings; and inferred that I resembled him in loving the vestiges of former years.
# 1712   But why is this man absent?
# 1290   These things she uttered as the shadows of the sweet twilight gathered darkly and more darkly around us and then, with a gentle pressure of her fairy like hand, overthrew, in a single sweet instant, all the argumentative fabric she had reared.
# 11727  One could not be sure that the sea and the ground were horizontal, hence the relative position of everything else seemed phantasmally variable.
# 14142  His demeanour would assume an unwonted grace and even dignity; and the sodden creatures around him would sense something of superiority something which made them less ready to give the usual kicks and cuffs to the poor butt and drudge.
# 1554   I believe I did ridiculous things such as offering prayers to Artemis, Latona, Demeter, Persephone, and Plouton.
# 11906  I am a part of this scene; each and all its properties are a part of me.
# 7711   Just as quietly, too, he walked toward the door, locked it and put the key in his pocket.
# 18217  And travellers now within that valley, Through the red litten windows, see Vast forms that move fantastically To a discordant melody; While, like a rapid ghastly river, Through the pale door, A hideous throng rush out forever, And laugh but smile no more.
# 19431  The old woman shuddered, she contrived at length to sit upright; but her teeth chattered, and her knees knocked together close, very close, lay a half naked figure, just discernible in the gloom, and the cry for water and the stifled moan were again uttered.
# 3894   Well meaning philosophers had taught him to look into the logical relations of things, and analyse the processes which shaped his thoughts and fancies.
# ...                                                                                                                                                        ...
# 8786   There are vocal qualities peculiar to men, and vocal qualities peculiar to beasts; and it is terrible to hear the one when the source should yield the other.
# 2473   and it made easy to her the bed of her death.
# 1922   Yet, mad am I not and very surely do I not dream.
# 15518  I leaned to the left.
# 18224  Can you not fancy the shout of scorn with which my words would be received by our progenitors were it possible for them to be now looking over my shoulder?
# 4130   On the night of the day on which this cruel deed was done, I was aroused from sleep by the cry of fire.
# 18039  Wouldn't pull it no go.
# 9785   The wind, which had fallen in the south, now rose with great violence in the west.
# 14225  The rubbish on the floor was picked up with the minutest care.
# 1954   To seek to describe it were useless for it was such that no description is possible.
# 1740   Shall I meet you again, after having traversed immense seas, and returned by the most southern cape of Africa or America?
# 1345   They were made to imitate the body of a creeping serpent, and were long and black, with a poisoned barb.
# 11227  Not a word had been spoken during the present session on any of these topics.
# 16095  Of their faces and forms I dare not speak in detail; for the mere remembrance makes me grow faint.
# 19083  Convinced myself, I seek not to convince.
# 16321  It was in the newspaper that she saw the advertisement for the design for a national gallery.
# 19374  Even the source of colonies was dried up, for in New Holland, Van Diemen's Land, and the Cape of Good Hope, plague raged.
# 5312   Of our studies it is impossible to speak, since they held so slight a connexion with anything of the world as living men conceive it.
# 13342  I found that the berries were spoiled by this operation, and the nuts and roots much improved.
# 6880   Listen You spoke thus: 'It is done it is most cheerfully agreed I sacrifice every feeling for your sake.
# 12457  My death is rapidly approaching and you are not near to watch the flitting and vanishing of my spirit.
# 12841  Why am I to give an account of myself?
# 12731  I arose, as I thought, a new man, and proceeded steadily and complacently on my unknown way.
# 407    He knew deeper vices through books, and he now longed to know them at first hand.
# 14695  My friend was dying when I spoke to him, and he could not answer coherently.
# 7093   The thatch had fallen in, the walls were unplastered, and the door was off its hinges.
# 9966   D , at Vienna once, did me an evil turn, which I told him, quite good humoredly, that I should remember.
# 14255  When you have read these hastily scrawled pages you may guess, though never fully realise, why it is that I must have forgetfulness or death.
# 3056   As the second landing was reached, these sounds, also, had ceased and everything remained perfectly quiet.
# 11443  Alas I even now look back with disgust at my artifices and contrivances by which, after many painful struggles, I effected my retreat.
#
# [1055 rows x 3 columns]

# %% [markdown]
# # Bayesian Optimization

# %%
from bayes_opt import BayesianOptimization
from matplotlib import gridspec
from sklearn.model_selection import cross_validate

# %%
# define the scoring function - cross validated score
def cv_score(model, X, y, scoring='accuracy', cv=3, n_jobs=3):
    val = cross_validate(model,
                         X,
                         y=y,
                         scoring=scoring,
                         cv=cv,
                         n_jobs=n_jobs)['test_score'].mean()
    return val

# %%
def NB_BO(clf__alpha):
    params = {"clf__alpha": clf__alpha}
    model = Pipeline([('emb', CountVectorizer()),
                     ('ftrf', TfidfTransformer()),
                     ('clf', MultinomialNB(alpha=clf__alpha))])
    score = cv_score(model, X, y, n_jobs=3)
    return score

# %%
SVC_BO = BayesianOptimization(NB_BO,
                             {"clf__alpha": (1e-4, 1)})

# %%
gp_params = {"alpha": 2e-5}
SVC_BO.maximize(n_iter=10, **gp_params, kappa=5)
# Out:
# Initialization
# --------------------------------------------
#  Step |   Time |      Value |   clf__alpha |
#     1 | 00m01s |    0.81873 |       0.6729 |
#     2 | 00m01s |    0.81526 |       0.7342 |
#     3 | 00m01s |    0.83722 |       0.2499 |
#     4 | 00m01s |    0.82400 |       0.5654 |
#     5 | 00m01s |    0.80791 |       0.8757 |
# Bayesian Optimization
# --------------------------------------------
#  Step |   Time |      Value |   clf__alpha |
#     6 | 00m02s |    0.80862 |       0.0001 |
#     7 | 00m02s |    0.83503 |       0.3190 |
#     8 | 00m03s |    0.83508 |       0.3223 |
#     9 | 00m03s |    0.83513 |       0.3249 |
#    10 | 00m03s |    0.83513 |       0.3286 |
#    11 | 00m03s |    0.80081 |       1.0000 |
#    12 | 00m04s |    0.83625 |       0.2885 |
#    13 | 00m04s |    0.83247 |       0.3827 |
#    14 | 00m04s |    0.83753 |       0.2458 |
#    15 | 00m05s |    0.83784 |       0.2389 |
